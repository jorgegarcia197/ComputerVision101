# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.0/613.0 kB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached opencv_python-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
# ...
#   Using cached PyYAML-6.0-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 13.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 12.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 13.4 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#   Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# ...
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO()
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 11.6MB/s]

# %%
model = YOLO('yolov8m.pt')
results = model('assets/myvideo.mp4', save=True)
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:04<00:00, 11.8MB/s]
#
#
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/327) /Users/jorgegarcia/Coding/Softtek/UDEM/ComputerVision/HandTracking/notebooks/assets/myvideo.mp4: 384x640 6 persons, 2 bicycles, 6 cars, 1 motorcycle, 4 buss, 1 backpack, 1 handbag, 179.1ms
# ...
